# %% [markdown]
# # 🧾 Product Sales Analysis — Pens & Printers
#
# ### 📍 Overview
# This project analyzes the sales performance of a new office stationery product line — **pens and printers** — launched by the fictional company *Pens and Printers*.
# The goal is to evaluate the effectiveness of different **sales methods** (Email, Call, and Email + Call) in driving revenue and customer engagement.
#
# ### 🎯 Objectives
# - Understand how each sales method impacts total revenue and sales volume.
# - Identify patterns and key factors influencing customer response.
# - Provide actionable insights to optimize future sales strategies.
#
# ### 🧰 Tools & Libraries
# - Python — data analysis and visualization
# - Pandas — data cleaning and manipulation
# - Matplotlib & Seaborn — exploratory data analysis and visualization
# - NumPy & SciPy — numerical operations and statistics
#
# ### 🧠 Key Questions
# 1. Which sales approach (Email, Call, or Email + Call) generated the highest revenue?
# 2. Do certain regions or product categories respond better to specific methods?
# 3. What recommendations can improve sales performance in future campaigns?

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset 
sales = pd.read_csv('https://s3.amazonaws.com/talent-assets.datacamp.com/product_sales.csv')
sales 
d
# Out:
#        week  sales_method                           customer_id  nb_sold  \
# 0         2         Email  2e72d641-95ac-497b-bbf8-4861764a7097       10
# 1         6  Email + Call  3998a98d-70f5-44f7-942e-789bb8ad2fe7       15
# 2         5          Call  d1de9884-8059-4065-b10f-86eef57e4a44       11
# 3         4         Email  78aa75a4-ffeb-4817-b1d0-2f030783c5d7       11
# 4         3         Email  10e6d446-10a5-42e5-8210-1b5438f70922        9
# ...     ...           ...                                   ...      ...
# 14995     4          Call  17267b41-d048-4346-8b90-7f787690a836       10
# 14996     5          Call  09e10d6f-4508-4b27-895e-4db11ce8302b       10
# 14997     1          Call  839653cb-68c9-48cb-a097-0a5a3b2b298b        7
# 14998     6          Call  e4dad70a-b23b-407c-8bd3-e32ea00fae17       13
# 14999     5  Email + Call  4e077235-7c17-4054-9997-7a890336a214       13
#
#        revenue  years_as_customer  nb_site_visits          state
# ...
